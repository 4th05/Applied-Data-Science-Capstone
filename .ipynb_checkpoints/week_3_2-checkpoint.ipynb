# %%
import pandas as pd
import geocoder

# %%
df = pd.read_pickle("List_of_postal_codes_of_Canada.pkl")

# %%
lats = [geocoder.arcgis('{}, Toronto, Ontario'.format(ps)).latlng for ps in df["Postal Code"]]

# %%
df["Latitude"] = list(list(zip(*lats))[0])
df["Longitude"] = list(list(zip(*lats))[1])

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood  Latitude  Longitude
# 0                                         Not assigned  43.64869  -79.38544
# 1                                         Not assigned  43.64869  -79.38544
# 2                                            Parkwoods  43.75188  -79.33036
# 3                                     Victoria Village  43.73042  -79.31282
# 4                            Regent Park, Harbourfront  43.65514  -79.36265
# ..                                                 ...       ...        ...
# ...
